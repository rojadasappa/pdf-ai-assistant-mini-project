# %% [markdown]
# # Assignment 1 - PDF Ingestion + RAG Q&A
# This notebook demonstrates PDF ingestion, chunking, vector storage, and RAG question answering.

# %%
from dotenv import load_dotenv
load_dotenv()
from src.pipeline import RagAssistantPipeline
pipeline = RagAssistantPipeline(collection_name="pdf_rag_notebook")

# %%
pdf_path = "data/sample.pdf"  # Replace with your PDF path
ingest_result = pipeline.ingest(pdf_path)
ingest_result

# %%
question = "What are the most important points from this document?"
qa_result = pipeline.ask(question)
print(qa_result["answer"])
qa_result["sources"]
