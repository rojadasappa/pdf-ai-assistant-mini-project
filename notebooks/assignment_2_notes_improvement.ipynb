# %% [markdown]
# # Assignment 2 - Notes + Iterative Improvement
# This notebook demonstrates structured notes generation and iterative answer improvement.

# %%
from dotenv import load_dotenv
load_dotenv()
from src.pipeline import RagAssistantPipeline
pipeline = RagAssistantPipeline(collection_name="pdf_rag_notebook")

# %%
topic = "Machine learning basics"
notes_result = pipeline.notes(topic)
print(notes_result["notes"])

# %%
question = "Explain the core ideas with practical examples"
iter_result = pipeline.iterative_answer(question, loops=3)
print("Initial:\n", iter_result["initial_answer"])
print("\nImproved:\n", iter_result["improved_answer"])
iter_result["evaluations"]
